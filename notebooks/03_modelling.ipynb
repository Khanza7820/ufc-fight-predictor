# %%
import sys
sys.path.append('..')
from src.walk_forward_cv import generate_walk_forward_folds, validate_no_leakage

import pandas as pd
df = pd.read_csv('../data/processed/features.csv')
df['date'] = pd.to_datetime(df['date'])
